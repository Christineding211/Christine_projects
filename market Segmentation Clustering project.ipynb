# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
creditcard_df  = pd.read_csv("Marketing_data.csv")

# %%
creditcard_df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
creditcard_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
creditcard_df.describe()
#Mean balance is $1564
#Purchases average is $1003, one off purchase average is ~$600
#Average purchases frequency is around 0.5
# Average tenure is 12 years
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
#the maximum of cash advance, and who made it ? 
creditcard_df['CASH_ADVANCE'].max()
creditcard_df[creditcard_df['CASH_ADVANCE']== 47137.21176]

# the customer has made 123 cash advance transactions and never paid credit card in full
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 2159  C12226  10905.05381                1.0     431.93             133.5
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 2159                  298.43   47137.21176             0.583333
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 2159                        0.25                               0.5
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 2159                     1.0               123             21       19600.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 2159  39048.59762       5394.173671               0.0      12

# %%
#see the missing data 
sns.heatmap(creditcard_df.isnull(), yticklabels = False, cbar = False, cmap="Blues")
# Out:
# <Axes: >

# %%
creditcard_df.isnull().sum()
#see total missing data in each column
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %% [raw]
# Fill up the missing elements with mean of the 'MINIMUM_PAYMENT'

# %%
# Calculate the mean of the 'MINIMUM_PAYMENTS' column excluding null values
mean_minimum_payments = creditcard_df['MINIMUM_PAYMENTS'].mean()
creditcard_df['MINIMUM_PAYMENTS'].fillna(mean_minimum_payments, inplace = True)

# %%
creditcard_df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        1
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %% [markdown]
# Fill the missing data with mean of the CREDIT_LIMIT

# %%
mean_credit_limit= creditcard_df['CREDIT_LIMIT'].mean()
creditcard_df['CREDIT_LIMIT'].fillna(mean_credit_limit, inplace = True)

# %%
creditcard_df.isnull().sum() # check again, now there's no missing data
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
# see the heatmap
sns.heatmap(creditcard_df.isnull(), yticklabels = False, cbar = False, cmap="Blues")
# Out:
# <Axes: >

# %%
#drop Customer ID since it has no meaning here
creditcard_df.drop('CUST_ID',axis = 1, inplace = True)

# %%
creditcard_df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
n = len(creditcard_df.columns)
print(n)
print(creditcard_df.columns)
# Out:
# 17
# Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
#        'TENURE'],
#       dtype='object')

# %%
correlations = creditcard_df.corr()

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(correlations, annot = True)
# Out:
# <Axes: >

# %% [raw]
# K-menas cluster : since different attributes have different scales, if calculate together for distance, the number with bigger will contribute most in distance, so need to scale the data first

# %%
scaler = StandardScaler()
creditcard_df_scaled = scaler.fit_transform(creditcard_df)

# %%
creditcard_df_scaled.shape #8950 rows and 17 columns
# Out:
# (8950, 17)

# %%
creditcard_df_scaled #Scales an attribute to be in the range [0..1]
# Out:
# array([[-0.73198937, -0.24943448, -0.42489974, ..., -0.31096755,
#         -0.52555097,  0.36067954],
#        [ 0.78696085,  0.13432467, -0.46955188, ...,  0.08931021,
#          0.2342269 ,  0.36067954],
#        [ 0.44713513,  0.51808382, -0.10766823, ..., -0.10166318,
#         -0.52555097,  0.36067954],
#        ...,
#        [-0.7403981 , -0.18547673, -0.40196519, ..., -0.33546549,
#          0.32919999, -4.12276757],
#        [-0.74517423, -0.18547673, -0.46955188, ..., -0.34690648,
#          0.32919999, -4.12276757],
#        [-0.57257511, -0.88903307,  0.04214581, ..., -0.33294642,
#         -0.52555097, -4.12276757]])

# %%
inertia = [] # store the within-cluster sum of squares
k_range = range(1,11)

for k in k_range:
    kmeans = KMeans(n_clusters=k,n_init=10)
    kmeans.fit(creditcard_df_scaled)
    inertia.append(kmeans.inertia_)

#  n_init=10: The warning informs start from scikit-learn version 1.4 ,define this just suppress this warning and ensure consistent behavior

# %%
# Plot the elbow curve
plt.plot(k_range, inertia, marker='o')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal k')
plt.show()

# the values does not reduce linearly until 8th cluster. so choose the number of clusters to be 7.

# %%
kmeans = KMeans(8, n_init=10)
kmeans.fit(creditcard_df_scaled)
labels = kmeans.labels_ #provide the label for each datapoint

# %%
labels
# Out:
# array([0, 2, 6, ..., 5, 5, 5], dtype=int32)

# %%
kmeans.cluster_centers_.shape 
#check the dimensions of the array, (8,17)means there are 8 cluster centers, and each cluster center has 17 features
# Out:
# (8, 17)

# %%
cluster_ceners = pd.DataFrame(data = kmeans.cluster_centers_, columns = [creditcard_df.columns])
cluster_ceners
# Out:
#     BALANCE BALANCE_FREQUENCY  PURCHASES ONEOFF_PURCHASES  \
# 0  0.006353          0.403514  -0.356070        -0.241097
# 1 -0.700925         -2.142134  -0.310284        -0.234754
# 2  1.667430          0.395588  -0.225275        -0.161315
# 3  1.819469          0.301643  12.207777        12.296446
# 4  1.047688          0.467311   2.473119         1.810078
# 5 -0.335649         -0.343331  -0.287578        -0.214344
# 6 -0.131266          0.399815   0.542446         0.671503
# 7 -0.361693          0.333651  -0.033867        -0.242981
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0              -0.398874    -0.102048           -0.847366
# 1              -0.302264    -0.320004           -0.554897
# 2              -0.236362     1.990509           -0.485984
# 3               6.272587     0.242957            1.002411
# 4               2.522298    -0.153852            1.166260
# 5              -0.285827     0.066601           -0.196918
# ...

# %%
creditcard_df_cluster = creditcard_df.assign(cluster=labels)
creditcard_df_cluster.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
labels.shape
# Out:
# (8950,)

# %%
labels.max()
# Out:
# 7

# %%
labels.min()
# Out:
# 0

# %%
# PCA cluster

pca = PCA(n_components = 2)
pca_comp = pca.fit_transform(creditcard_df_scaled)
pca_comp
# Out:
# array([[-1.68222146, -1.07645938],
#        [-1.13830118,  2.50640712],
#        [ 0.96968429, -0.38352151],
#        ...,
#        [-0.92620264, -1.81076818],
#        [-2.33654952, -0.6579376 ],
#        [-0.5564196 , -0.4004498 ]])

# %%
pca_df = pd.DataFrame(data = pca_comp, columns = ['pca1','pca2'])
pca_df.head()
# Out:
#        pca1      pca2
# 0 -1.682221 -1.076459
# 1 -1.138301  2.506407
# 2  0.969684 -0.383522
# 3 -0.873630  0.043142
# 4 -1.599434 -0.688577

# %%
pca_df = pd.concat([pca_df, pd.DataFrame({'cluster':labels})],axis =1)
pca_df.head()
# Out:
#        pca1      pca2  cluster
# 0 -1.682221 -1.076459        0
# 1 -1.138301  2.506407        2
# 2  0.969684 -0.383522        6
# 3 -0.873630  0.043142        0
# 4 -1.599434 -0.688577        0

# %%
plt.figure(figsize = (10,10))
ax = sns.scatterplot(x = 'pca1', y = 'pca2', hue = 'cluster', data = pca_df, palette = ['red','green','blue','pink','gray','yellow','purple','black'])
